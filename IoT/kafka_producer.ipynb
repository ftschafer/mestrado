# %% [markdown]
# # Steps
#
# The work is divided into three stages:
#
# - Data and Producer
# - Data Processing
# - Processed Data
#
# The Jupyter notebook is documented alongside the development of the algorithm, continuing the presentation for the Internet of Things course.
#
# ![title](Images/cap.png)

# %% [markdown]
# # 1 - Data Collection with Kafka Producer
# ![title](Images/cap_1.png)

# %% [markdown]
# Importing the Necessary Libraries

# %%
import subprocess
from kafka import KafkaProducer
import json
import time

# %% [markdown]
# 1.1 - Producing Data via Kafka
#
# Before producing the data, previously executed topics are closed. The idea behind this code is to assume that the sensor logs already return historical data for a specific period, thus avoiding the duplication of information.

# %%
kafka_topics_cmd = '/home/alberthsoliveira/Downloads/kafka_2.13-3.7.0/bin/kafka-topics.sh'

def delete_kafka_topic(topic_name):
    try:
        subprocess.run([kafka_topics_cmd, '--bootstrap-server', 'localhost:9092', '--delete', '--topic', topic_name], check=True)
    except subprocess.CalledProcessError as e:
        pass

def create_kafka_topic(topic_name):
    try:
        subprocess.run([kafka_topics_cmd, '--bootstrap-server', 'localhost:9092', '--create', '--topic', topic_name, '--partitions', '1', '--replication-factor', '1'], check=True)
    except subprocess.CalledProcessError as e:
        pass

producer = KafkaProducer(
    bootstrap_servers='localhost:9092',  
    value_serializer=lambda v: json.dumps(v).encode('utf-8')  
)

topic_name = 'sensor_data'

delete_kafka_topic(topic_name)
time.sleep(5)  
create_kafka_topic(topic_name)

with open('data.json', 'r') as file:
    dados = json.load(file)

for data in dados:
    print(data)
    producer.send(topic_name, value=data)

producer.flush()
# Out:
# WARNING: Due to limitations in metric names, topics with a period ('.') or underscore ('_') could collide. To avoid issues it is best to use either, but not both.
# Error while executing topic command : Topic 'sensor_data' already exists.
# [2024-06-29 14:22:05,328] ERROR org.apache.kafka.common.errors.TopicExistsException: Topic 'sensor_data' already exists.
#  (org.apache.kafka.tools.TopicCommand)
# {'id_pumps': 1, 'timestamp': '2024-06-27 00:00:00', 'temperature': 19.53, 'fuel': 26.41, 'water': 3066.87}
# {'id_pumps': 2, 'timestamp': '2024-06-27 00:00:00', 'temperature': 49.53, 'fuel': 84.24, 'water': 4871.02}
# {'id_pumps': 3, 'timestamp': '2024-06-27 00:00:00', 'temperature': 48.1, 'fuel': 89.71, 'water': 2028.99}
# {'id_pumps': 1, 'timestamp': '2024-06-27 00:30:00', 'temperature': 11.12, 'fuel': 99.3, 'water': 3980.58}
# {'id_pumps': 2, 'timestamp': '2024-06-27 00:30:00', 'temperature': 25.55, 'fuel': 89.72, 'water': 2586.94}
# {'id_pumps': 3, 'timestamp': '2024-06-27 00:30:00', 'temperature': 11.7, 'fuel': 89.11, 'water': 1449.12}
# {'id_pumps': 1, 'timestamp': '2024-06-27 01:00:00', 'temperature': 17.57, 'fuel': 57.67, 'water': 1062.65}
# {'id_pumps': 2, 'timestamp': '2024-06-27 01:00:00', 'temperature': 39.13, 'fuel': 78.9, 'water': 1348.2}
# {'id_pumps': 3, 'timestamp': '2024-06-27 01:00:00', 'temperature': 0.67, 'fuel': 20.71, 'water': 1305.03}
# {'id_pumps': 1, 'timestamp': '2024-06-27 01:30:00', 'temperature': 32.46, 'fuel': 31.55, 'water': 3738.65}
# {'id_pumps': 2, 'timestamp': '2024-06-27 01:30:00', 'temperature': 46.99, 'fuel': 40.79, 'water': 4800.57}
# {'id_pumps': 3, 'timestamp': '2024-06-27 01:30:00', 'temperature': 41.95, 'fuel': 96.22, 'water': 1745.19}
# {'id_pumps': 1, 'timestamp': '2024-06-27 02:00:00', 'temperature': 5.36, 'fuel': 17.26, 'water': 3039.82}
# {'id_pumps': 2, 'timestamp': '2024-06-27 02:00:00', 'temperature': 4.92, 'fuel': 80.78, 'water': 1407.09}
# {'id_pumps': 3, 'timestamp': '2024-06-27 02:00:00', 'temperature': 48.88, 'fuel': 51.06, 'water': 1909.34}
# {'id_pumps': 1, 'timestamp': '2024-06-27 02:30:00', 'temperature': 40.98, 'fuel': 64.93, 'water': 2847.8}
# {'id_pumps': 2, 'timestamp': '2024-06-27 02:30:00', 'temperature': 49.4, 'fuel': 23.9, 'water': 1102.31}
# {'id_pumps': 3, 'timestamp': '2024-06-27 02:30:00', 'temperature': 0.21, 'fuel': 50.08, 'water': 2836.57}
# {'id_pumps': 1, 'timestamp': '2024-06-27 03:00:00', 'temperature': 44.02, 'fuel': 44.79, 'water': 829.51}
# {'id_pumps': 2, 'timestamp': '2024-06-27 03:00:00', 'temperature': 14.25, 'fuel': 61.7, 'water': 585.41}
# {'id_pumps': 3, 'timestamp': '2024-06-27 03:00:00', 'temperature': 49.82, 'fuel': 28.85, 'water': 700.81}
# {'id_pumps': 1, 'timestamp': '2024-06-27 03:30:00', 'temperature': 15.28, 'fuel': 45.05, 'water': 4033.28}
# {'id_pumps': 2, 'timestamp': '2024-06-27 03:30:00', 'temperature': 22.0, 'fuel': 87.34, 'water': 2355.15}
# {'id_pumps': 3, 'timestamp': '2024-06-27 03:30:00', 'temperature': 17.22, 'fuel': 76.52, 'water': 4623.86}
# {'id_pumps': 1, 'timestamp': '2024-06-27 04:00:00', 'temperature': 49.33, 'fuel': 83.22, 'water': 2021.59}
# {'id_pumps': 2, 'timestamp': '2024-06-27 04:00:00', 'temperature': 48.76, 'fuel': 16.64, 'water': 4962.84}
# {'id_pumps': 3, 'timestamp': '2024-06-27 04:00:00', 'temperature': 12.33, 'fuel': 24.89, 'water': 3137.99}
# {'id_pumps': 1, 'timestamp': '2024-06-27 04:30:00', 'temperature': 19.57, 'fuel': 1.66, 'water': 2423.11}
# {'id_pumps': 2, 'timestamp': '2024-06-27 04:30:00', 'temperature': 41.07, 'fuel': 6.88, 'water': 2838.75}
# {'id_pumps': 3, 'timestamp': '2024-06-27 04:30:00', 'temperature': 25.84, 'fuel': 7.99, 'water': 4794.09}
# {'id_pumps': 1, 'timestamp': '2024-06-27 05:00:00', 'temperature': 48.63, 'fuel': 11.78, 'water': 1400.43}
# {'id_pumps': 2, 'timestamp': '2024-06-27 05:00:00', 'temperature': 10.25, 'fuel': 59.08, 'water': 4373.8}
# {'id_pumps': 3, 'timestamp': '2024-06-27 05:00:00', 'temperature': 32.08, 'fuel': 91.84, 'water': 2559.71}
# {'id_pumps': 1, 'timestamp': '2024-06-27 05:30:00', 'temperature': 46.51, 'fuel': 82.24, 'water': 1095.37}
# {'id_pumps': 2, 'timestamp': '2024-06-27 05:30:00', 'temperature': 26.59, 'fuel': 72.66, 'water': 1253.34}
# {'id_pumps': 3, 'timestamp': '2024-06-27 05:30:00', 'temperature': 12.35, 'fuel': 19.37, 'water': 2075.36}
# {'id_pumps': 1, 'timestamp': '2024-06-27 06:00:00', 'temperature': 47.25, 'fuel': 51.42, 'water': 4514.57}
# {'id_pumps': 2, 'timestamp': '2024-06-27 06:00:00', 'temperature': 9.78, 'fuel': 72.65, 'water': 3741.59}
# {'id_pumps': 3, 'timestamp': '2024-06-27 06:00:00', 'temperature': 1.3, 'fuel': 96.89, 'water': 1310.4}
# {'id_pumps': 1, 'timestamp': '2024-06-27 06:30:00', 'temperature': 0.08, 'fuel': 59.15, 'water': 4395.08}
# {'id_pumps': 2, 'timestamp': '2024-06-27 06:30:00', 'temperature': 4.88, 'fuel': 10.41, 'water': 3575.39}
# {'id_pumps': 3, 'timestamp': '2024-06-27 06:30:00', 'temperature': 4.16, 'fuel': 30.79, 'water': 2500.84}
# {'id_pumps': 1, 'timestamp': '2024-06-27 07:00:00', 'temperature': 7.0, 'fuel': 13.41, 'water': 3001.26}
# {'id_pumps': 2, 'timestamp': '2024-06-27 07:00:00', 'temperature': 32.14, 'fuel': 35.32, 'water': 3902.13}
# {'id_pumps': 3, 'timestamp': '2024-06-27 07:00:00', 'temperature': 27.33, 'fuel': 78.34, 'water': 4327.29}
# {'id_pumps': 1, 'timestamp': '2024-06-27 07:30:00', 'temperature': 22.79, 'fuel': 99.53, 'water': 2870.25}
# {'id_pumps': 2, 'timestamp': '2024-06-27 07:30:00', 'temperature': 14.91, 'fuel': 16.93, 'water': 4601.68}
# {'id_pumps': 3, 'timestamp': '2024-06-27 07:30:00', 'temperature': 29.19, 'fuel': 71.36, 'water': 3510.23}
# {'id_pumps': 1, 'timestamp': '2024-06-27 08:00:00', 'temperature': 29.68, 'fuel': 59.19, 'water': 3013.14}
# {'id_pumps': 2, 'timestamp': '2024-06-27 08:00:00', 'temperature': 45.67, 'fuel': 50.63, 'water': 1159.87}
# {'id_pumps': 3, 'timestamp': '2024-06-27 08:00:00', 'temperature': 37.57, 'fuel': 35.06, 'water': 1218.92}
# {'id_pumps': 1, 'timestamp': '2024-06-27 08:30:00', 'temperature': 27.65, 'fuel': 46.16, 'water': 2989.67}
# {'id_pumps': 2, 'timestamp': '2024-06-27 08:30:00', 'temperature': 10.11, 'fuel': 95.57, 'water': 4411.24}
# {'id_pumps': 3, 'timestamp': '2024-06-27 08:30:00', 'temperature': 6.49, 'fuel': 77.95, 'water': 4298.46}
# {'id_pumps': 1, 'timestamp': '2024-06-27 09:00:00', 'temperature': 26.07, 'fuel': 27.62, 'water': 2788.13}
# {'id_pumps': 2, 'timestamp': '2024-06-27 09:00:00', 'temperature': 18.44, 'fuel': 14.34, 'water': 3031.95}
# {'id_pumps': 3, 'timestamp': '2024-06-27 09:00:00', 'temperature': 47.53, 'fuel': 26.37, 'water': 4287.62}
# {'id_pumps': 1, 'timestamp': '2024-06-27 09:30:00', 'temperature': 46.34, 'fuel': 4.36, 'water': 159.78}
# {'id_pumps': 2, 'timestamp': '2024-06-27 09:30:00', 'temperature': 38.85, 'fuel': 6.75, 'water': 722.97}
# {'id_pumps': 3, 'timestamp': '2024-06-27 09:30:00', 'temperature': 47.49, 'fuel': 0.1, 'water': 898.56}
# {'id_pumps': 1, 'timestamp': '2024-06-27 10:00:00', 'temperature': 40.93, 'fuel': 45.2, 'water': 3826.1}
# {'id_pumps': 2, 'timestamp': '2024-06-27 10:00:00', 'temperature': 20.17, 'fuel': 58.27, 'water': 4072.17}
# {'id_pumps': 3, 'timestamp': '2024-06-27 10:00:00', 'temperature': 19.69, 'fuel': 88.67, 'water': 4015.03}
# {'id_pumps': 1, 'timestamp': '2024-06-27 10:30:00', 'temperature': 47.89, 'fuel': 38.53, 'water': 1305.2}
# {'id_pumps': 2, 'timestamp': '2024-06-27 10:30:00', 'temperature': 28.41, 'fuel': 74.0, 'water': 4888.98}
# {'id_pumps': 3, 'timestamp': '2024-06-27 10:30:00', 'temperature': 25.43, 'fuel': 81.87, 'water': 1776.61}
# {'id_pumps': 1, 'timestamp': '2024-06-27 11:00:00', 'temperature': 25.06, 'fuel': 82.72, 'water': 4966.72}
# {'id_pumps': 2, 'timestamp': '2024-06-27 11:00:00', 'temperature': 31.64, 'fuel': 91.1, 'water': 2747.92}
# {'id_pumps': 3, 'timestamp': '2024-06-27 11:00:00', 'temperature': 33.84, 'fuel': 64.88, 'water': 4927.31}
# {'id_pumps': 1, 'timestamp': '2024-06-27 11:30:00', 'temperature': 36.96, 'fuel': 78.11, 'water': 3062.95}
# {'id_pumps': 2, 'timestamp': '2024-06-27 11:30:00', 'temperature': 28.9, 'fuel': 92.28, 'water': 1976.37}
# {'id_pumps': 3, 'timestamp': '2024-06-27 11:30:00', 'temperature': 3.76, 'fuel': 32.12, 'water': 1217.7}
# {'id_pumps': 1, 'timestamp': '2024-06-27 12:00:00', 'temperature': 79.39, 'fuel': 99.99, 'water': 2661.93}
# {'id_pumps': 2, 'timestamp': '2024-06-27 12:00:00', 'temperature': 62.95, 'fuel': 14.12, 'water': 3693.24}
# {'id_pumps': 3, 'timestamp': '2024-06-27 12:00:00', 'temperature': 52.02, 'fuel': 60.22, 'water': 1122.34}
# {'id_pumps': 1, 'timestamp': '2024-06-27 12:30:00', 'temperature': 40.65, 'fuel': 42.2, 'water': 2532.67}
# {'id_pumps': 2, 'timestamp': '2024-06-27 12:30:00', 'temperature': 26.99, 'fuel': 46.8, 'water': 4911.85}
# {'id_pumps': 3, 'timestamp': '2024-06-27 12:30:00', 'temperature': 25.77, 'fuel': 11.98, 'water': 3149.14}
# {'id_pumps': 1, 'timestamp': '2024-06-27 13:00:00', 'temperature': 74.85, 'fuel': 39.37, 'water': 3794.71}
# {'id_pumps': 2, 'timestamp': '2024-06-27 13:00:00', 'temperature': 79.46, 'fuel': 61.0, 'water': 3373.43}
# {'id_pumps': 3, 'timestamp': '2024-06-27 13:00:00', 'temperature': 72.73, 'fuel': 35.02, 'water': 4743.91}
# {'id_pumps': 1, 'timestamp': '2024-06-27 13:30:00', 'temperature': 8.57, 'fuel': 62.94, 'water': 2896.84}
# {'id_pumps': 2, 'timestamp': '2024-06-27 13:30:00', 'temperature': 34.37, 'fuel': 58.55, 'water': 1480.58}
# {'id_pumps': 3, 'timestamp': '2024-06-27 13:30:00', 'temperature': 19.33, 'fuel': 66.93, 'water': 4866.02}
# {'id_pumps': 1, 'timestamp': '2024-06-27 14:00:00', 'temperature': 44.57, 'fuel': 78.42, 'water': 3617.84}
# {'id_pumps': 2, 'timestamp': '2024-06-27 14:00:00', 'temperature': 48.37, 'fuel': 52.32, 'water': 3102.06}
# {'id_pumps': 3, 'timestamp': '2024-06-27 14:00:00', 'temperature': 9.13, 'fuel': 56.86, 'water': 1215.95}
# {'id_pumps': 1, 'timestamp': '2024-06-27 14:30:00', 'temperature': 75.97, 'fuel': 56.83, 'water': 3391.13}
# {'id_pumps': 2, 'timestamp': '2024-06-27 14:30:00', 'temperature': 92.02, 'fuel': 13.03, 'water': 3106.79}
# {'id_pumps': 3, 'timestamp': '2024-06-27 14:30:00', 'temperature': 60.07, 'fuel': 77.67, 'water': 2726.28}
# {'id_pumps': 1, 'timestamp': '2024-06-27 15:00:00', 'temperature': 38.31, 'fuel': 8.41, 'water': 4854.44}
# {'id_pumps': 2, 'timestamp': '2024-06-27 15:00:00', 'temperature': 1.35, 'fuel': 6.75, 'water': 3389.1}
# {'id_pumps': 3, 'timestamp': '2024-06-27 15:00:00', 'temperature': 46.83, 'fuel': 4.05, 'water': 1142.08}
# {'id_pumps': 1, 'timestamp': '2024-06-27 15:30:00', 'temperature': 19.98, 'fuel': 25.43, 'water': 4164.33}
# {'id_pumps': 2, 'timestamp': '2024-06-27 15:30:00', 'temperature': 49.97, 'fuel': 34.02, 'water': 4717.64}
# {'id_pumps': 3, 'timestamp': '2024-06-27 15:30:00', 'temperature': 46.11, 'fuel': 29.43, 'water': 2562.17}
# {'id_pumps': 1, 'timestamp': '2024-06-27 16:00:00', 'temperature': 71.14, 'fuel': 20.04, 'water': 1612.99}
# {'id_pumps': 2, 'timestamp': '2024-06-27 16:00:00', 'temperature': 85.79, 'fuel': 90.16, 'water': 4284.45}
# {'id_pumps': 3, 'timestamp': '2024-06-27 16:00:00', 'temperature': 53.25, 'fuel': 19.92, 'water': 1595.95}
# {'id_pumps': 1, 'timestamp': '2024-06-27 16:30:00', 'temperature': 4.37, 'fuel': 7.31, 'water': 2922.77}
# {'id_pumps': 2, 'timestamp': '2024-06-27 16:30:00', 'temperature': 47.74, 'fuel': 8.39, 'water': 3847.46}
# {'id_pumps': 3, 'timestamp': '2024-06-27 16:30:00', 'temperature': 14.3, 'fuel': 4.97, 'water': 1747.66}
# {'id_pumps': 1, 'timestamp': '2024-06-27 17:00:00', 'temperature': 44.04, 'fuel': 49.1, 'water': 3506.58}
# {'id_pumps': 2, 'timestamp': '2024-06-27 17:00:00', 'temperature': 41.25, 'fuel': 45.02, 'water': 1859.62}
# {'id_pumps': 3, 'timestamp': '2024-06-27 17:00:00', 'temperature': 31.52, 'fuel': 23.18, 'water': 3498.77}
# {'id_pumps': 1, 'timestamp': '2024-06-27 17:30:00', 'temperature': 2.16, 'fuel': 80.83, 'water': 473.03}
# {'id_pumps': 2, 'timestamp': '2024-06-27 17:30:00', 'temperature': 27.16, 'fuel': 92.35, 'water': 462.32}
# {'id_pumps': 3, 'timestamp': '2024-06-27 17:30:00', 'temperature': 45.71, 'fuel': 61.16, 'water': 564.36}
# {'id_pumps': 1, 'timestamp': '2024-06-27 18:00:00', 'temperature': 32.32, 'fuel': 92.6, 'water': 3801.67}
# {'id_pumps': 2, 'timestamp': '2024-06-27 18:00:00', 'temperature': 0.81, 'fuel': 34.81, 'water': 2637.33}
# {'id_pumps': 3, 'timestamp': '2024-06-27 18:00:00', 'temperature': 24.51, 'fuel': 96.5, 'water': 4535.02}
# {'id_pumps': 1, 'timestamp': '2024-06-27 18:30:00', 'temperature': 71.3, 'fuel': 90.3, 'water': 722.55}
# {'id_pumps': 2, 'timestamp': '2024-06-27 18:30:00', 'temperature': 51.73, 'fuel': 30.75, 'water': 527.91}
# {'id_pumps': 3, 'timestamp': '2024-06-27 18:30:00', 'temperature': 52.1, 'fuel': 52.45, 'water': 549.95}
# {'id_pumps': 1, 'timestamp': '2024-06-27 19:00:00', 'temperature': 54.65, 'fuel': 84.3, 'water': 1259.4}
# {'id_pumps': 2, 'timestamp': '2024-06-27 19:00:00', 'temperature': 95.62, 'fuel': 10.91, 'water': 4389.64}
# {'id_pumps': 3, 'timestamp': '2024-06-27 19:00:00', 'temperature': 64.57, 'fuel': 42.25, 'water': 4438.64}
# {'id_pumps': 1, 'timestamp': '2024-06-27 19:30:00', 'temperature': 19.49, 'fuel': 77.7, 'water': 995.19}
# {'id_pumps': 2, 'timestamp': '2024-06-27 19:30:00', 'temperature': 33.24, 'fuel': 77.19, 'water': 413.61}
# {'id_pumps': 3, 'timestamp': '2024-06-27 19:30:00', 'temperature': 9.86, 'fuel': 41.3, 'water': 835.31}
# {'id_pumps': 1, 'timestamp': '2024-06-27 20:00:00', 'temperature': 2.43, 'fuel': 58.21, 'water': 4877.44}
# {'id_pumps': 2, 'timestamp': '2024-06-27 20:00:00', 'temperature': 42.72, 'fuel': 68.66, 'water': 4090.16}
# {'id_pumps': 3, 'timestamp': '2024-06-27 20:00:00', 'temperature': 25.05, 'fuel': 71.85, 'water': 4626.5}
# {'id_pumps': 1, 'timestamp': '2024-06-27 20:30:00', 'temperature': 14.19, 'fuel': 1.59, 'water': 2426.51}
# {'id_pumps': 2, 'timestamp': '2024-06-27 20:30:00', 'temperature': 11.32, 'fuel': 6.57, 'water': 4811.21}
# {'id_pumps': 3, 'timestamp': '2024-06-27 20:30:00', 'temperature': 35.31, 'fuel': 2.28, 'water': 4617.44}
# {'id_pumps': 1, 'timestamp': '2024-06-27 21:00:00', 'temperature': 1.81, 'fuel': 85.43, 'water': 1451.02}
# {'id_pumps': 2, 'timestamp': '2024-06-27 21:00:00', 'temperature': 19.31, 'fuel': 70.14, 'water': 2597.16}
# {'id_pumps': 3, 'timestamp': '2024-06-27 21:00:00', 'temperature': 26.24, 'fuel': 48.99, 'water': 3646.41}
# {'id_pumps': 1, 'timestamp': '2024-06-27 21:30:00', 'temperature': 11.31, 'fuel': 92.58, 'water': 2129.29}
# {'id_pumps': 2, 'timestamp': '2024-06-27 21:30:00', 'temperature': 44.77, 'fuel': 71.86, 'water': 1472.33}
# {'id_pumps': 3, 'timestamp': '2024-06-27 21:30:00', 'temperature': 31.59, 'fuel': 70.75, 'water': 1572.02}
# {'id_pumps': 1, 'timestamp': '2024-06-27 22:00:00', 'temperature': 43.2, 'fuel': 62.61, 'water': 30.74}
# {'id_pumps': 2, 'timestamp': '2024-06-27 22:00:00', 'temperature': 47.51, 'fuel': 94.48, 'water': 171.14}
# {'id_pumps': 3, 'timestamp': '2024-06-27 22:00:00', 'temperature': 20.69, 'fuel': 57.81, 'water': 942.6}
# {'id_pumps': 1, 'timestamp': '2024-06-27 22:30:00', 'temperature': 34.21, 'fuel': 98.23, 'water': 2934.55}
# {'id_pumps': 2, 'timestamp': '2024-06-27 22:30:00', 'temperature': 15.72, 'fuel': 43.34, 'water': 4536.84}
# {'id_pumps': 3, 'timestamp': '2024-06-27 22:30:00', 'temperature': 14.94, 'fuel': 43.28, 'water': 1398.14}
# {'id_pumps': 1, 'timestamp': '2024-06-27 23:00:00', 'temperature': 45.66, 'fuel': 5.28, 'water': 1694.24}
# {'id_pumps': 2, 'timestamp': '2024-06-27 23:00:00', 'temperature': 13.42, 'fuel': 4.29, 'water': 2894.5}
# {'id_pumps': 3, 'timestamp': '2024-06-27 23:00:00', 'temperature': 11.87, 'fuel': 5.04, 'water': 2777.95}
# {'id_pumps': 1, 'timestamp': '2024-06-27 23:30:00', 'temperature': 24.05, 'fuel': 34.04, 'water': 4197.99}
# {'id_pumps': 2, 'timestamp': '2024-06-27 23:30:00', 'temperature': 18.08, 'fuel': 31.44, 'water': 4150.54}
# {'id_pumps': 3, 'timestamp': '2024-06-27 23:30:00', 'temperature': 48.0, 'fuel': 89.85, 'water': 2913.99}
